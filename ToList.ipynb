# %%
import os
import pandas as pd

# 構成銘柄一覧を正規化
nikkei_semiconductor_constituents = [
    {'Code': '4043', 'Name': 'トクヤマ', 'Sector': '化学'},
    {'Code': '4063', 'Name': '信越化学工業', 'Sector': '化学'},
    {'Code': '4186', 'Name': '東京応化工業', 'Sector': '化学'},
    {'Code': '4203', 'Name': '住友ベークライト', 'Sector': '化学'},
    {'Code': '4272', 'Name': '日本化薬', 'Sector': '化学'},
    {'Code': '4369', 'Name': 'トリケミカル研究所', 'Sector': '化学'},
    {'Code': '4401', 'Name': 'ＡＤＥＫＡ', 'Sector': '化学'},
    {'Code': '4626', 'Name': '太陽ホールディングス', 'Sector': '化学'},
    {'Code': '4980', 'Name': 'デクセリアルズ', 'Sector': '化学'},
    {'Code': '3436', 'Name': 'ＳＵＭＣＯ', 'Sector': '非鉄・金属'},
    {'Code': '6315', 'Name': 'ＴＯＷＡ', 'Sector': '機械'},
    {'Code': '6323', 'Name': 'ローツェ', 'Sector': '機械'},
    {'Code': '6526', 'Name': 'ソシオネクスト', 'Sector': '電気機器'}, 
    {'Code': '6707', 'Name': 'サンケン電気', 'Sector': '電気機器'},
    {'Code': '6723', 'Name': 'ルネサスエレクトロニクス', 'Sector': '電気機器'},
    {'Code': '6728', 'Name': 'アルバック', 'Sector': '電気機器'},
    {'Code': '6758', 'Name': 'ソニーグループ', 'Sector': '電気機器'},
    {'Code': '6857', 'Name': 'アドバンテスト', 'Sector': '電気機器'},
    {'Code': '6890', 'Name': 'フェローテックホールディングス', 'Sector': '電気機器'},
    {'Code': '6920', 'Name': 'レーザーテック', 'Sector': '電気機器'},
    {'Code': '6963', 'Name': 'ローム', 'Sector': '電気機器'},
    {'Code': '7735', 'Name': 'ＳＣＲＥＥＮホールディングス', 'Sector': '電気機器'},
    {'Code': '8035', 'Name': '東京エレクトロン', 'Sector': '電気機器'},
    {'Code': '6146', 'Name': 'ディスコ', 'Sector': '精密機器'},
    {'Code': '7729', 'Name': '東京精密', 'Sector': '精密機器'},
    {'Code': '7741', 'Name': 'ＨＯＹＡ', 'Sector': '精密機器'},
    {'Code': '2760', 'Name': '東京エレクトロン　デバイス', 'Sector': '商社'},
    {'Code': '3132', 'Name': 'マクニカホールディングス', 'Sector': '商社'},
    {'Code': '8154', 'Name': '加賀電子', 'Sector': '商社'}
]

df_constituents = pd.DataFrame(nikkei_semiconductor_constituents)

# 構成銘柄一覧を保存
STORAGE_DIR_PATH = fr"C:\Users\100ca\Documents\PyCode\jquants-api-client-python\code\data"

constituents_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_constituents.csv"
df_constituents.to_csv(constituents_file, index=False)

# %%
refresh_token = "eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.N8MYP3Ckh3ajJhVrdxthB5EhawxMdq_0xsuK88oWEWMWSI1Bqqd0Lnw059CUAa9cpiz4dnBe8u9xaRH45s2MAkEGYlJKFSPI_g6xBI3uvFwq1UjliwVDPYk4S00eGy4PNcuoJU-XPl_YPZjkoVZMNyKBxJVQanKsUZOuLsm4RitdPc9FPDN6YbWJM4-3aQ3XsuWcpk7dtBtK2y4emKQ5eHXZ2WDqkn4TzAroeAwFXNUS3Sbj7JLT_eV8mvCF4pFgMNjR3YAMmEZOZiXXs7HPS9QIEviarKJ-qa7V_fyW5ns3Lhsbaj_2oG-yNwGGo7qb7YbENQDqIan7avmXqV8T_A.xncrf9wyZKL3Zpec.xCr-HTBZ0jBYtGkihfP5LdrvICHIXhDeTMT6SG-IU-k8pJOGkQvdvrJlicvcShPsXYVdKom6gtSJgsIxe75J66R--hPn3V5Z9Mf1XxeTBg5gEkShbxqMGGJfHCVt7xOnEuR5mTwvJaZzplNg43F31icVUCWrtpQueQ0pbhBqeIYBYFmA4BFHWvblNU-KzF7Ue5MxGv1_f38stAOeU9_ELVt0hinVnSoNu-Lq0HtGUEtLsh12zgGx_lK9_Ars1pCoTwGtKeALxxNeLCX5fPvOPNsdiddq_3JGDTK2dQXle31ylpRCMhJcAVrL3BJumPU4vdEjq5fARY6VtC3grGuAZZGLtaYxRYPfEZh-ifheWF1MgEdtA85d0UWwZOiKqIQhDBaLS2rq_1l0glgnf47dQJkzrdZldb7vEWhQZ8J-FETXrW1KkYb2DV-hu2-_9jtYfjd4ixAFCJuQ1OC5we0XUVXtPhxfPp0k15jlarXpPhe9thSsNPNDEafMm5hFNCXrXDnz5vy5hFEvwlofB3iXPfF8GoWTmkut5Biqd5ZT0wBhdKiKywCd358Nq0VbZLzBet0dxEtPQGQB-zUSSIQG08ChcCV_GzdQXoVO3qJQjb7X2cUpby-L6OZgPMGNEEzH-7xHNf3BY9B_YQPtvQWrUG4UIYpQ_4yFoKi0Zd2a39swsAPt_zv_j0fHD5ocefz2xmyFVIm53Sah4wuSQJqEwNVMAMyEZWem4wEqtuaVLmxtUj6ilDyyPeRwu_w-nagsUkIEmg1UH8JxoloKJQvSA3any0BVh9s9IB7LleBur62pCvJQreBfczVJ8PrD1YOPVNFAJF3RKL-UswAb2egUytB8GwZQK9EnmvYxGfRRYlWYC1g8s22bBnETMYbA2qXGRYZzweZt4zngAO4EuUpUIDDrs9f-8d__8F3O6ls0rQUZ6WBOSpHSkSNqKC7I9BswRoD-TbVrbdZGyYNf25mojKZfyq9BJiXADSZU2UyShAUKG80oPmePBUgWvi6erTIHkE18YKxe_xuazaijHlYBHSyJ-4US9kR4PNOxA0vIyfWl7jKsgUv1ofSQSeMJ9PxigF0DvIG9089HzGxBdzZlVJPXtQb9I3MhVK0UHJwZ7BmX4DlcoMrWaCtGo9zd4L33PQ_iB0GsmnngFlIaaRzOZo3oLZrFAhJ6uYfN9UqsOlic_sL75IsJF4IE6klZafakLBGef0EHJKdzf9_QiZx5TPigGV0wr63BHTlDRqcOtyB4XOBp9CqngRvxSc-9_-Qc3k1a05u2ODrgaSl70iuAUjDOQxuDdhPr5kIscv6xyQwtqsHJb_gL_GMRLZAUnULoq7WMZnfUipWFEQ.PJ1iLNhPGLuzCmg1HrueDA"#@param {type: "string"}

# %%
import os
from datetime import datetime
import pandas as pd
import jquantsapi

# JQuants APIクライアントの初期化 (ご自身の認証情報を使用してください)
jqapi = jquantsapi.Client(refresh_token=refresh_token)

# 保存した構成銘柄一覧を読み込み
constituents_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_constituents.csv"
if os.path.exists(constituents_file):
    df_constituents = pd.read_csv(constituents_file)
    nikkei_semiconductor_codes = df_constituents['Code'].tolist()
else:
    raise FileNotFoundError(f"構成銘柄一覧ファイルが見つかりません: {constituents_file}")

# 財務データ取得の開始日と終了日を設定
now = pd.Timestamp.now(tz="Asia/Tokyo")
start_dt = now - pd.Timedelta(700, unit="D") 
end_dt = now - pd.Timedelta(85, unit="D")
if end_dt.hour < 1:
    end_dt -= pd.Timedelta(1, unit="D")

# 日経半導体株指数構成銘柄の財務データを取得
df_nikkei_semiconductor_fin = pd.DataFrame()
for code in nikkei_semiconductor_codes:
    df_fin = jqapi.get_fins_statements(code=code)
    
    # タイムゾーン情報を設定
    df_fin['DisclosedDate'] = pd.to_datetime(df_fin['DisclosedDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentPeriodEndDate'] = pd.to_datetime(df_fin['CurrentPeriodEndDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentFiscalYearStartDate'] = pd.to_datetime(df_fin['CurrentFiscalYearStartDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentFiscalYearEndDate'] = pd.to_datetime(df_fin['CurrentFiscalYearEndDate']).dt.tz_localize('Asia/Tokyo')
    
    df_fin = df_fin[(df_fin['DisclosedDate'] >= start_dt) & (df_fin['DisclosedDate'] <= end_dt)]
    df_nikkei_semiconductor_fin = pd.concat([df_nikkei_semiconductor_fin, df_fin])

# 日付でソート  
df_nikkei_semiconductor_fin.sort_values(["DisclosedDate", "DisclosedTime"], inplace=True)

# 結果を保存
statements_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_statements_{start_dt.strftime('%Y%m%d')}_{end_dt.strftime('%Y%m%d')}.csv.gz" 
df_nikkei_semiconductor_fin.to_csv(statements_file, compression="gzip", index=False)

# %%
df_nikkei_semiconductor_fin
# Out:
#                DisclosedDate DisclosedTime LocalCode DisclosureNumber  \
# 1  2022-07-27 00:00:00+09:00      09:00:00     40430   20220707596327
# 1  2022-07-27 00:00:00+09:00      15:00:00     40630   20220726504671
# 1  2022-07-27 00:00:00+09:00      15:30:00     46260   20220726504654
# 1  2022-07-27 00:00:00+09:00      15:30:00     77350   20220726505051
# 2  2022-07-27 00:00:00+09:00      15:30:00     27600   20220727505561
# ..                       ...           ...       ...              ...
# 7  2024-02-14 00:00:00+09:00      15:00:00     34360   20240208530466
# 7  2024-02-14 00:00:00+09:00      15:00:00     67580   20240214535656
# 8  2024-02-14 00:00:00+09:00      15:30:00     68900   20240213535327
# 11 2024-02-29 00:00:00+09:00      15:00:00     42030   20240228544805
# 7  2024-03-15 00:00:00+09:00      15:00:00     43690   20240227543227
#
#                              TypeOfDocument TypeOfCurrentPeriod  \
# 1     1QFinancialStatements_Consolidated_JP                  1Q
# 1     1QFinancialStatements_Consolidated_JP                  1Q
# 1     1QFinancialStatements_Consolidated_JP                  1Q
# 1     1QFinancialStatements_Consolidated_JP                  1Q
# 2     1QFinancialStatements_Consolidated_JP                  1Q
# ..                                      ...                 ...
# 7     FYFinancialStatements_Consolidated_JP                  FY
# 7   3QFinancialStatements_Consolidated_IFRS                  3Q
# 8     3QFinancialStatements_Consolidated_JP                  3Q
# 11                 DividendForecastRevision                  FY
# 7     FYFinancialStatements_Consolidated_JP                  FY
#
#    CurrentPeriodStartDate      CurrentPeriodEndDate  \
# 1              2022-04-01 2022-06-30 00:00:00+09:00
# 1              2022-04-01 2022-06-30 00:00:00+09:00
# 1              2022-04-01 2022-06-30 00:00:00+09:00
# 1              2022-04-01 2022-06-30 00:00:00+09:00
# 2              2022-04-01 2022-06-30 00:00:00+09:00
# ..                    ...                       ...
# 7              2023-01-01 2023-12-31 00:00:00+09:00
# 7              2023-04-01 2023-12-31 00:00:00+09:00
# 8              2023-04-01 2023-12-31 00:00:00+09:00
# 11             2023-04-01 2024-03-31 00:00:00+09:00
# 7              2023-02-01 2024-01-31 00:00:00+09:00
#
#    CurrentFiscalYearStartDate  CurrentFiscalYearEndDate  ...  \
# 1   2022-04-01 00:00:00+09:00 2023-03-31 00:00:00+09:00  ...
# 1   2022-04-01 00:00:00+09:00 2023-03-31 00:00:00+09:00  ...
# 1   2022-04-01 00:00:00+09:00 2023-03-31 00:00:00+09:00  ...
# 1   2022-04-01 00:00:00+09:00 2023-03-31 00:00:00+09:00  ...
# 2   2022-04-01 00:00:00+09:00 2023-03-31 00:00:00+09:00  ...
# ..                        ...                       ...  ...
# 7   2023-01-01 00:00:00+09:00 2023-12-31 00:00:00+09:00  ...
# 7   2023-04-01 00:00:00+09:00 2024-03-31 00:00:00+09:00  ...
# 8   2023-04-01 00:00:00+09:00 2024-03-31 00:00:00+09:00  ...
# 11  2023-04-01 00:00:00+09:00 2024-03-31 00:00:00+09:00  ...
# 7   2023-02-01 00:00:00+09:00 2024-01-31 00:00:00+09:00  ...
#
#    ForecastNonConsolidatedNetSales ForecastNonConsolidatedOperatingProfit  \
# 1
# 1
# 1
# 1
# 2
# ..                             ...                                    ...
# 7
# 7
# 8
# 11
# 7
#
#    ForecastNonConsolidatedOrdinaryProfit ForecastNonConsolidatedProfit  \
# 1
# 1
# 1
# 1
# 2
# ..                                   ...                           ...
# 7
# 7
# 8
# 11
# 7
#
#    ForecastNonConsolidatedEarningsPerShare  \
# 1
# 1
# 1
# 1
# 2
# ..                                     ...
# 7
# 7
# 8
# 11
# 7
#
#    NextYearForecastNonConsolidatedNetSales  \
# 1
# 1
# 1
# 1
# 2
# ..                                     ...
# 7
# 7
# 8
# 11
# 7
#
#    NextYearForecastNonConsolidatedOperatingProfit  \
# 1
# 1
# 1
# 1
# 2
# ..                                            ...
# 7
# 7
# 8
# 11
# 7
#
#    NextYearForecastNonConsolidatedOrdinaryProfit  \
# 1
# 1
# 1
# 1
# 2
# ..                                           ...
# 7
# 7
# 8
# 11
# 7
#
#    NextYearForecastNonConsolidatedProfit  \
# 1
# 1
# 1
# 1
# 2
# ..                                   ...
# 7
# 7
# 8
# 11
# 7
#
#    NextYearForecastNonConsolidatedEarningsPerShare
# 1
# 1
# 1
# 1
# 2
# ..                                             ...
# 7
# 7
# 8
# 11
# 7
#
# [226 rows x 106 columns]

# %%
import os
from datetime import datetime
import pandas as pd
import jquantsapi

# JQuants APIクライアントの初期化 (ご自身の認証情報を使用してください)
jqapi = jquantsapi.Client(refresh_token=refresh_token)

# 保存した構成銘柄一覧を読み込み
constituents_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_constituents.csv"
if os.path.exists(constituents_file):
    df_constituents = pd.read_csv(constituents_file)
    nikkei_semiconductor_codes = df_constituents['Code'].tolist()
else:
    raise FileNotFoundError(f"構成銘柄一覧ファイルが見つかりません: {constituents_file}")

# 財務データ取得の開始日と終了日を設定
now = pd.Timestamp.now(tz="Asia/Tokyo")
start_dt = now - pd.Timedelta(700, unit="D") 
end_dt = now - pd.Timedelta(85, unit="D")
if end_dt.hour < 1:
    end_dt -= pd.Timedelta(1, unit="D")

# 日経半導体株指数構成銘柄の財務データを取得
df_nikkei_semiconductor_fin = pd.DataFrame()
for code in nikkei_semiconductor_codes:
    df_fin = jqapi.get_fins_statements(code=code)
    
    # タイムゾーン情報を設定
    df_fin['DisclosedDate'] = pd.to_datetime(df_fin['DisclosedDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentPeriodEndDate'] = pd.to_datetime(df_fin['CurrentPeriodEndDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentFiscalYearStartDate'] = pd.to_datetime(df_fin['CurrentFiscalYearStartDate']).dt.tz_localize('Asia/Tokyo')
    df_fin['CurrentFiscalYearEndDate'] = pd.to_datetime(df_fin['CurrentFiscalYearEndDate']).dt.tz_localize('Asia/Tokyo')
    
    df_fin = df_fin[(df_fin['DisclosedDate'] >= start_dt) & (df_fin['DisclosedDate'] <= end_dt)]
    
    # 'Code' 列を追加
    df_fin['Code'] = code
    
    df_nikkei_semiconductor_fin = pd.concat([df_nikkei_semiconductor_fin, df_fin])

# 日付でソート  
df_nikkei_semiconductor_fin.sort_values(["DisclosedDate", "DisclosedTime"], inplace=True)

# 結果を保存
statements_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_statements_{start_dt.strftime('%Y%m%d')}_{end_dt.strftime('%Y%m%d')}.csv" 
df_nikkei_semiconductor_fin.to_csv(statements_file, index=False)

# 保存したファイルを読み込み、欠損値処理と銘柄名の追加
df_nikkei_semiconductor_fin = pd.read_csv(statements_file)
df_nikkei_semiconductor_fin.dropna(how='all', axis=0, inplace=True)  # 行方向の欠損値処理
df_nikkei_semiconductor_fin.dropna(how='all', axis=1, inplace=True)  # 列方向の欠損値処理
df_nikkei_semiconductor_fin = pd.merge(df_nikkei_semiconductor_fin, df_constituents, on='Code', how='left')  # 銘柄名の追加

# 最終結果を保存
final_statements_file = f"{STORAGE_DIR_PATH}/nikkei_semiconductor_statements_final_{start_dt.strftime('%Y%m%d')}_{end_dt.strftime('%Y%m%d')}.csv"
df_nikkei_semiconductor_fin.to_csv(final_statements_file, index=False)

# %%
df_nikkei_semiconductor_fin.sort_values(by="Code").set_index("Name")
# Out:
#                            DisclosedDate DisclosedTime  LocalCode  \
# Name
# 東京エレクトロン　デバイス  2022-09-29 00:00:00+09:00      15:30:00      27600
# 東京エレクトロン　デバイス  2023-10-31 00:00:00+09:00      15:30:00      27600
# 東京エレクトロン　デバイス  2023-08-01 00:00:00+09:00      17:30:00      27600
# 東京エレクトロン　デバイス  2022-10-28 00:00:00+09:00      15:30:00      27600
# 東京エレクトロン　デバイス  2023-04-27 00:00:00+09:00      18:00:00      27600
# ...                                  ...           ...        ...
# 加賀電子           2022-11-08 00:00:00+09:00      15:00:00      81540
# 加賀電子           2023-08-03 00:00:00+09:00      15:00:00      81540
# 加賀電子           2023-05-11 00:00:00+09:00      15:00:00      81540
# 加賀電子           2023-11-08 00:00:00+09:00      15:00:00      81540
# 加賀電子           2022-08-04 00:00:00+09:00      15:00:00      81540
#
#                DisclosureNumber                         TypeOfDocument  \
# Name
# 東京エレクトロン　デバイス    20220927536714                   EarnForecastRevision
# 東京エレクトロン　デバイス    20231031575658  2QFinancialStatements_Consolidated_JP
# 東京エレクトロン　デバイス    20230801531832  1QFinancialStatements_Consolidated_JP
# 東京エレクトロン　デバイス    20221028552301  2QFinancialStatements_Consolidated_JP
# 東京エレクトロン　デバイス    20230427555282  FYFinancialStatements_Consolidated_JP
# ...                         ...                                    ...
# 加賀電子             20221107558360  2QFinancialStatements_Consolidated_JP
# 加賀電子             20230802532989  1QFinancialStatements_Consolidated_JP
# 加賀電子             20230511565502  FYFinancialStatements_Consolidated_JP
# 加賀電子             20231108581786  2QFinancialStatements_Consolidated_JP
# 加賀電子             20220803511084  1QFinancialStatements_Consolidated_JP
#
#               TypeOfCurrentPeriod CurrentPeriodStartDate  \
# Name
# 東京エレクトロン　デバイス                  2Q             2022-04-01
# 東京エレクトロン　デバイス                  2Q             2023-04-01
# 東京エレクトロン　デバイス                  1Q             2023-04-01
# 東京エレクトロン　デバイス                  2Q             2022-04-01
# 東京エレクトロン　デバイス                  FY             2022-04-01
# ...                           ...                    ...
# 加賀電子                           2Q             2022-04-01
# 加賀電子                           1Q             2023-04-01
# 加賀電子                           FY             2022-04-01
# 加賀電子                           2Q             2023-04-01
# 加賀電子                           1Q             2022-04-01
#
#                     CurrentPeriodEndDate CurrentFiscalYearStartDate  \
# Name
# 東京エレクトロン　デバイス  2022-09-30 00:00:00+09:00  2022-04-01 00:00:00+09:00
# 東京エレクトロン　デバイス  2023-09-30 00:00:00+09:00  2023-04-01 00:00:00+09:00
# 東京エレクトロン　デバイス  2023-06-30 00:00:00+09:00  2023-04-01 00:00:00+09:00
# 東京エレクトロン　デバイス  2022-09-30 00:00:00+09:00  2022-04-01 00:00:00+09:00
# 東京エレクトロン　デバイス  2023-03-31 00:00:00+09:00  2022-04-01 00:00:00+09:00
# ...                                  ...                        ...
# 加賀電子           2022-09-30 00:00:00+09:00  2022-04-01 00:00:00+09:00
# 加賀電子           2023-06-30 00:00:00+09:00  2023-04-01 00:00:00+09:00
# 加賀電子           2023-03-31 00:00:00+09:00  2022-04-01 00:00:00+09:00
# 加賀電子           2023-09-30 00:00:00+09:00  2023-04-01 00:00:00+09:00
# 加賀電子           2022-06-30 00:00:00+09:00  2022-04-01 00:00:00+09:00
#
#                 CurrentFiscalYearEndDate  ...  \
# Name                                      ...
# 東京エレクトロン　デバイス  2023-03-31 00:00:00+09:00  ...
# 東京エレクトロン　デバイス  2024-03-31 00:00:00+09:00  ...
# 東京エレクトロン　デバイス  2024-03-31 00:00:00+09:00  ...
# 東京エレクトロン　デバイス  2023-03-31 00:00:00+09:00  ...
# 東京エレクトロン　デバイス  2023-03-31 00:00:00+09:00  ...
# ...                                  ...  ...
# 加賀電子           2023-03-31 00:00:00+09:00  ...
# 加賀電子           2024-03-31 00:00:00+09:00  ...
# 加賀電子           2023-03-31 00:00:00+09:00  ...
# 加賀電子           2024-03-31 00:00:00+09:00  ...
# 加賀電子           2023-03-31 00:00:00+09:00  ...
#
#               ForecastNonConsolidatedOperatingProfit  \
# Name
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# ...                                              ...
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
#
#               ForecastNonConsolidatedOrdinaryProfit  \
# Name
# 東京エレクトロン　デバイス                                   NaN
# 東京エレクトロン　デバイス                                   NaN
# 東京エレクトロン　デバイス                                   NaN
# 東京エレクトロン　デバイス                                   NaN
# 東京エレクトロン　デバイス                                   NaN
# ...                                             ...
# 加賀電子                                            NaN
# 加賀電子                                            NaN
# 加賀電子                                            NaN
# 加賀電子                                            NaN
# 加賀電子                                            NaN
#
#                ForecastNonConsolidatedProfit  \
# Name
# 東京エレクトロン　デバイス                            NaN
# 東京エレクトロン　デバイス                            NaN
# 東京エレクトロン　デバイス                            NaN
# 東京エレクトロン　デバイス                            NaN
# 東京エレクトロン　デバイス                            NaN
# ...                                      ...
# 加賀電子                                     NaN
# 加賀電子                                     NaN
# 加賀電子                                     NaN
# 加賀電子                                     NaN
# 加賀電子                                     NaN
#
#                ForecastNonConsolidatedEarningsPerShare  \
# Name
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# ...                                                ...
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
#
#                NextYearForecastNonConsolidatedNetSales  \
# Name
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# 東京エレクトロン　デバイス                                      NaN
# ...                                                ...
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
# 加賀電子                                               NaN
#
#                NextYearForecastNonConsolidatedOrdinaryProfit  \
# Name
# 東京エレクトロン　デバイス                                            NaN
# 東京エレクトロン　デバイス                                            NaN
# 東京エレクトロン　デバイス                                            NaN
# 東京エレクトロン　デバイス                                            NaN
# 東京エレクトロン　デバイス                                            NaN
# ...                                                      ...
# 加賀電子                                                     NaN
# 加賀電子                                                     NaN
# 加賀電子                                                     NaN
# 加賀電子                                                     NaN
# 加賀電子                                                     NaN
#
#                NextYearForecastNonConsolidatedProfit  \
# Name
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# 東京エレクトロン　デバイス                                    NaN
# ...                                              ...
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
# 加賀電子                                             NaN
#
#                NextYearForecastNonConsolidatedEarningsPerShare  Code  Sector
# Name
# 東京エレクトロン　デバイス                                              NaN  2760      商社
# 東京エレクトロン　デバイス                                              NaN  2760      商社
# 東京エレクトロン　デバイス                                              NaN  2760      商社
# 東京エレクトロン　デバイス                                              NaN  2760      商社
# 東京エレクトロン　デバイス                                              NaN  2760      商社
# ...                                                        ...   ...     ...
# 加賀電子                                                       NaN  8154      商社
# 加賀電子                                                       NaN  8154      商社
# 加賀電子                                                       NaN  8154      商社
# 加賀電子                                                       NaN  8154      商社
# 加賀電子                                                       NaN  8154      商社
#
# [226 rows x 95 columns]

# %%
import pandas as pd

# データの読み込み
df = pd.read_csv(fr"{STORAGE_DIR_PATH}/nikkei_semiconductor_statements_final_20220724_20240330.csv")

# 日時データをdatetime形式に変換
date_cols = ['DisclosedDate', 'CurrentPeriodEndDate', 'CurrentFiscalYearStartDate', 'CurrentFiscalYearEndDate', 'NextFiscalYearStartDate', 'NextFiscalYearEndDate']
for col in date_cols:
    df[col] = pd.to_datetime(df[col])

# 決算期の表記を統一（例: 2022Q1, 2022Q2, ...）
df['Quarter'] = pd.PeriodIndex(df['CurrentPeriodEndDate'], freq='Q').strftime('%YQ%q')

# ピボット変換
df_pivoted = df.pivot_table(index=['Code', 'Name'], 
                            columns='Quarter', 
                            values=['NetSales', 'OperatingProfit', 'OrdinaryProfit', 'Profit'],
                            aggfunc='first')

# カラムのマルチインデックスを整形
df_pivoted.columns = [f'{col[1]} {col[0]}' for col in df_pivoted.columns]

# インデックスの名前をリセット
df_pivoted = df_pivoted.reset_index()

# 欠損値を0で埋める
df_pivoted = df_pivoted.fillna(0)

# ダブルカラムの例: 2022年と2023年の通期の当期純利益を比較
df_doublecolumn = df.pivot_table(index=['Code', 'Name'], 
                                 columns=df['CurrentPeriodEndDate'].dt.year, 
                                 values='Profit',
                                 aggfunc='sum')

df_doublecolumn = df_doublecolumn.reset_index()
df_doublecolumn = df_doublecolumn.fillna(0)

# 結果の保存
df_pivoted.to_csv(fr"{STORAGE_DIR_PATH}/nikkei_semiconductor_financial_data_pivoted.csv", index=False)
df_doublecolumn.to_csv(fr"{STORAGE_DIR_PATH}/nikkei_semiconductor_profit_doublecolumn.csv", index=False)

# %%
df_pivoted.columns
# Out:
# Index(['Code', 'Name', '2022Q2 NetSales', '2022Q3 NetSales', '2022Q4 NetSales',
#        '2023Q1 NetSales', '2023Q2 NetSales', '2023Q3 NetSales',
#        '2023Q4 NetSales', '2024Q1 NetSales', '2022Q2 OperatingProfit',
#        '2022Q3 OperatingProfit', '2022Q4 OperatingProfit',
#        '2023Q1 OperatingProfit', '2023Q2 OperatingProfit',
#        '2023Q3 OperatingProfit', '2023Q4 OperatingProfit',
#        '2024Q1 OperatingProfit', '2022Q2 OrdinaryProfit',
#        '2022Q3 OrdinaryProfit', '2022Q4 OrdinaryProfit',
#        '2023Q1 OrdinaryProfit', '2023Q2 OrdinaryProfit',
#        '2023Q3 OrdinaryProfit', '2023Q4 OrdinaryProfit',
#        '2024Q1 OrdinaryProfit', '2022Q2 Profit', '2022Q3 Profit',
#        '2022Q4 Profit', '2023Q1 Profit', '2023Q2 Profit', '2023Q3 Profit',
#        '2023Q4 Profit', '2024Q1 Profit'],
#       dtype='object')

# %%
df_nikkei_semiconductor_fin
# Out:
#                  DisclosedDate DisclosedTime  LocalCode  DisclosureNumber  \
# 0    2022-07-27 00:00:00+09:00      09:00:00      40430    20220707596327
# 1    2022-07-27 00:00:00+09:00      15:00:00      40630    20220726504671
# 2    2022-07-27 00:00:00+09:00      15:30:00      46260    20220726504654
# 3    2022-07-27 00:00:00+09:00      15:30:00      77350    20220726505051
# 4    2022-07-27 00:00:00+09:00      15:30:00      27600    20220727505561
# ..                         ...           ...        ...               ...
# 221  2024-02-14 00:00:00+09:00      15:00:00      34360    20240208530466
# 222  2024-02-14 00:00:00+09:00      15:00:00      67580    20240214535656
# 223  2024-02-14 00:00:00+09:00      15:30:00      68900    20240213535327
# 224  2024-02-29 00:00:00+09:00      15:00:00      42030    20240228544805
# 225  2024-03-15 00:00:00+09:00      15:00:00      43690    20240227543227
#
#                               TypeOfDocument TypeOfCurrentPeriod  \
# 0      1QFinancialStatements_Consolidated_JP                  1Q
# 1      1QFinancialStatements_Consolidated_JP                  1Q
# 2      1QFinancialStatements_Consolidated_JP                  1Q
# 3      1QFinancialStatements_Consolidated_JP                  1Q
# 4      1QFinancialStatements_Consolidated_JP                  1Q
# ..                                       ...                 ...
# 221    FYFinancialStatements_Consolidated_JP                  FY
# 222  3QFinancialStatements_Consolidated_IFRS                  3Q
# 223    3QFinancialStatements_Consolidated_JP                  3Q
# 224                 DividendForecastRevision                  FY
# 225    FYFinancialStatements_Consolidated_JP                  FY
#
#     CurrentPeriodStartDate       CurrentPeriodEndDate  \
# 0               2022-04-01  2022-06-30 00:00:00+09:00
# 1               2022-04-01  2022-06-30 00:00:00+09:00
# 2               2022-04-01  2022-06-30 00:00:00+09:00
# 3               2022-04-01  2022-06-30 00:00:00+09:00
# 4               2022-04-01  2022-06-30 00:00:00+09:00
# ..                     ...                        ...
# 221             2023-01-01  2023-12-31 00:00:00+09:00
# 222             2023-04-01  2023-12-31 00:00:00+09:00
# 223             2023-04-01  2023-12-31 00:00:00+09:00
# 224             2023-04-01  2024-03-31 00:00:00+09:00
# 225             2023-02-01  2024-01-31 00:00:00+09:00
#
#     CurrentFiscalYearStartDate   CurrentFiscalYearEndDate  ...  \
# 0    2022-04-01 00:00:00+09:00  2023-03-31 00:00:00+09:00  ...
# 1    2022-04-01 00:00:00+09:00  2023-03-31 00:00:00+09:00  ...
# 2    2022-04-01 00:00:00+09:00  2023-03-31 00:00:00+09:00  ...
# 3    2022-04-01 00:00:00+09:00  2023-03-31 00:00:00+09:00  ...
# 4    2022-04-01 00:00:00+09:00  2023-03-31 00:00:00+09:00  ...
# ..                         ...                        ...  ...
# 221  2023-01-01 00:00:00+09:00  2023-12-31 00:00:00+09:00  ...
# 222  2023-04-01 00:00:00+09:00  2024-03-31 00:00:00+09:00  ...
# 223  2023-04-01 00:00:00+09:00  2024-03-31 00:00:00+09:00  ...
# 224  2023-04-01 00:00:00+09:00  2024-03-31 00:00:00+09:00  ...
# 225  2023-02-01 00:00:00+09:00  2024-01-31 00:00:00+09:00  ...
#
#     ForecastNonConsolidatedOrdinaryProfit ForecastNonConsolidatedProfit  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
# ..                                    ...                           ...
# 221                                   NaN                           NaN
# 222                                   NaN                           NaN
# 223                                   NaN                           NaN
# 224                                   NaN                           NaN
# 225                                   NaN                           NaN
#
#      ForecastNonConsolidatedEarningsPerShare  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 221                                      NaN
# 222                                      NaN
# 223                                      NaN
# 224                                      NaN
# 225                                      NaN
#
#      NextYearForecastNonConsolidatedNetSales  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 221                                      NaN
# 222                                      NaN
# 223                                      NaN
# 224                                      NaN
# 225                                      NaN
#
#      NextYearForecastNonConsolidatedOrdinaryProfit  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 221                                            NaN
# 222                                            NaN
# 223                                            NaN
# 224                                            NaN
# 225                                            NaN
#
#      NextYearForecastNonConsolidatedProfit  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 221                                    NaN
# 222                                    NaN
# 223                                    NaN
# 224                                    NaN
# 225                                    NaN
#
#      NextYearForecastNonConsolidatedEarningsPerShare  Code             Name  \
# 0                                                NaN  4043             トクヤマ
# 1                                                NaN  4063           信越化学工業
# 2                                                NaN  4626       太陽ホールディングス
# 3                                                NaN  7735   ＳＣＲＥＥＮホールディングス
# 4                                                NaN  2760    東京エレクトロン　デバイス
# ..                                               ...   ...              ...
# 221                                              NaN  3436            ＳＵＭＣＯ
# 222                                              NaN  6758          ソニーグループ
# 223                                              NaN  6890  フェローテックホールディングス
# 224                                              NaN  4203         住友ベークライト
# 225                                              NaN  4369        トリケミカル研究所
#
#      Sector
# 0        化学
# 1        化学
# 2        化学
# 3      電気機器
# 4        商社
# ..      ...
# 221   非鉄・金属
# 222    電気機器
# 223    電気機器
# 224      化学
# 225      化学
#
# [226 rows x 96 columns]

# %%
#company_data = df_pivoted[df_pivoted["Name"]=="ＨＯＹＡ"]
df_melted = pd.melt(df_pivoted, id_vars=['Code', 'Name'], var_name='Quarter', value_name='Value')

# 'Quarter'を'Metric'と'Quarter'に分割
df_melted[['Quarter','Metric']] = df_melted['Quarter'].str.split(expand=True)
#company_data = df_melted[df_melted["Name"]=="ＨＯＹＡ"]
df_melted
# Out:
#      Code            Name Quarter         Value    Metric
# 0    2760   東京エレクトロン　デバイス  2022Q2  5.067700e+10  NetSales
# 1    3132    マクニカホールディングス  2022Q2  2.413200e+11  NetSales
# 2    3436           ＳＵＭＣＯ  2022Q2  2.074120e+11  NetSales
# 3    4043            トクヤマ  2022Q2  8.401700e+10  NetSales
# 4    4063          信越化学工業  2022Q2  6.567070e+11  NetSales
# ..    ...             ...     ...           ...       ...
# 923  7729            東京精密  2024Q1  0.000000e+00    Profit
# 924  7735  ＳＣＲＥＥＮホールディングス  2024Q1  0.000000e+00    Profit
# 925  7741            ＨＯＹＡ  2024Q1  0.000000e+00    Profit
# 926  8035        東京エレクトロン  2024Q1  0.000000e+00    Profit
# 927  8154            加賀電子  2024Q1  0.000000e+00    Profit
#
# [928 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# データを再構成
df_melted = pd.melt(df_pivoted, id_vars=['Code', 'Name'], var_name='Quarter', value_name='Value')

# 'Quarter'を'Metric'と'Quarter'に分割
df_melted[['Metric', 'Quarter']] = df_melted['Quarter'].str.split(expand=True)

# 'Quarter'から年を取り出す
df_melted['Year'] = df_melted['Quarter'].str[:4]

df_melted = df_melted[['Code', 'Name', 'Year', 'Quarter', 'Metric', 'Value']]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_melted[df_melted['Metric'].isin(['NetSales', 'OperatingProfit'])], 
             x='Quarter', y='Value', hue='Name', style='Metric')
plt.title('売上高と営業利益の推移')
plt.xlabel('決算期')
plt.ylabel('金額（円）')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.tight_layout()
plt.show()
df_melted
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 27770 (\N{CJK UNIFIED IDEOGRAPH-6C7A}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 31639 (\N{CJK UNIFIED IDEOGRAPH-7B97}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 38989 (\N{CJK UNIFIED IDEOGRAPH-984D}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 20870 (\N{CJK UNIFIED IDEOGRAPH-5186}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 21942 (\N{CJK UNIFIED IDEOGRAPH-55B6}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 26989 (\N{CJK UNIFIED IDEOGRAPH-696D}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 30410 (\N{CJK UNIFIED IDEOGRAPH-76CA}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 25512 (\N{CJK UNIFIED IDEOGRAPH-63A8}) missing from current font.
#   plt.tight_layout()
# C:\Users\100ca\AppData\Local\Temp\ipykernel_22696\1469451681.py:24: UserWarning: Glyph 31227 (\N{CJK UNIFIED IDEOGRAPH-79FB}) missing from current font.
#   plt.tight_layout()
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38989 (\N{CJK UNIFIED IDEOGRAPH-984D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20870 (\N{CJK UNIFIED IDEOGRAPH-5186}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21942 (\N{CJK UNIFIED IDEOGRAPH-55B6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26989 (\N{CJK UNIFIED IDEOGRAPH-696D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30410 (\N{CJK UNIFIED IDEOGRAPH-76CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25512 (\N{CJK UNIFIED IDEOGRAPH-63A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31227 (\N{CJK UNIFIED IDEOGRAPH-79FB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27770 (\N{CJK UNIFIED IDEOGRAPH-6C7A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31639 (\N{CJK UNIFIED IDEOGRAPH-7B97}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\100ca\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
#      Code            Name  Year   Quarter  Metric         Value
# 0    2760   東京エレクトロン　デバイス  NetS  NetSales  2022Q2  5.067700e+10
# 1    3132    マクニカホールディングス  NetS  NetSales  2022Q2  2.413200e+11
# 2    3436           ＳＵＭＣＯ  NetS  NetSales  2022Q2  2.074120e+11
# 3    4043            トクヤマ  NetS  NetSales  2022Q2  8.401700e+10
# 4    4063          信越化学工業  NetS  NetSales  2022Q2  6.567070e+11
# ..    ...             ...   ...       ...     ...           ...
# 923  7729            東京精密  Prof    Profit  2024Q1  0.000000e+00
# 924  7735  ＳＣＲＥＥＮホールディングス  Prof    Profit  2024Q1  0.000000e+00
# 925  7741            ＨＯＹＡ  Prof    Profit  2024Q1  0.000000e+00
# 926  8035        東京エレクトロン  Prof    Profit  2024Q1  0.000000e+00
# 927  8154            加賀電子  Prof    Profit  2024Q1  0.000000e+00
#
# [928 rows x 6 columns]

# %%
df_melted[df_melted["Name"]=="ＨＯＹＡ"]
# Out:
#      Code  Name  Year          Quarter  Metric         Value
# 26   7741  ＨＯＹＡ  NetS         NetSales  2022Q2  1.801790e+11
# 55   7741  ＨＯＹＡ  NetS         NetSales  2022Q3  3.642910e+11
# 84   7741  ＨＯＹＡ  NetS         NetSales  2022Q4  5.378160e+11
# 113  7741  ＨＯＹＡ  NetS         NetSales  2023Q1  7.235820e+11
# 142  7741  ＨＯＹＡ  NetS         NetSales  2023Q2  1.822880e+11
# 171  7741  ＨＯＹＡ  NetS         NetSales  2023Q3  3.709890e+11
# 200  7741  ＨＯＹＡ  NetS         NetSales  2023Q4  5.657870e+11
# 229  7741  ＨＯＹＡ  NetS         NetSales  2024Q1  0.000000e+00
# 258  7741  ＨＯＹＡ  Oper  OperatingProfit  2022Q2  0.000000e+00
# 287  7741  ＨＯＹＡ  Oper  OperatingProfit  2022Q3  0.000000e+00
# 316  7741  ＨＯＹＡ  Oper  OperatingProfit  2022Q4  0.000000e+00
# 345  7741  ＨＯＹＡ  Oper  OperatingProfit  2023Q1  0.000000e+00
# 374  7741  ＨＯＹＡ  Oper  OperatingProfit  2023Q2  0.000000e+00
# 403  7741  ＨＯＹＡ  Oper  OperatingProfit  2023Q3  0.000000e+00
# 432  7741  ＨＯＹＡ  Oper  OperatingProfit  2023Q4  0.000000e+00
# 461  7741  ＨＯＹＡ  Oper  OperatingProfit  2024Q1  0.000000e+00
# 490  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2022Q2  0.000000e+00
# 519  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2022Q3  0.000000e+00
# 548  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2022Q4  0.000000e+00
# 577  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2023Q1  0.000000e+00
# 606  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2023Q2  0.000000e+00
# 635  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2023Q3  0.000000e+00
# 664  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2023Q4  0.000000e+00
# 693  7741  ＨＯＹＡ  Ordi   OrdinaryProfit  2024Q1  0.000000e+00
# 722  7741  ＨＯＹＡ  Prof           Profit  2022Q2  4.835800e+10
# 751  7741  ＨＯＹＡ  Prof           Profit  2022Q3  9.545900e+10
# 780  7741  ＨＯＹＡ  Prof           Profit  2022Q4  1.260850e+11
# 809  7741  ＨＯＹＡ  Prof           Profit  2023Q1  1.686380e+11
# 838  7741  ＨＯＹＡ  Prof           Profit  2023Q2  3.821500e+10
# 867  7741  ＨＯＹＡ  Prof           Profit  2023Q3  8.563300e+10
# 896  7741  ＨＯＹＡ  Prof           Profit  2023Q4  1.242860e+11
# 925  7741  ＨＯＹＡ  Prof           Profit  2024Q1  0.000000e+00
